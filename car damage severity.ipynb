# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
import zipfile
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define file paths
zip_path = "/content/drive/MyDrive/car damage severity.v1i.coco-segmentation.zip"  # Change to your actual file path
extract_path = "/content/car_damage_dataset_coco"  # Destination folder

# Create extract directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction complete! Files are in:", extract_path)
# Out:
# Mounted at /content/drive
# Extraction complete! Files are in: /content/car_damage_dataset_coco

# %%
# install dependencies
# !pip install -U torch torchvision cython
# !pip install -U 'git+https://github.com/facebookresearch/fvcore.git' 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
import torch, torchvision
torch.__version__
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting git+https://github.com/facebookresearch/fvcore.git
#   Cloning https://github.com/facebookresearch/fvcore.git to /tmp/pip-req-build-4m60jw_7
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/fvcore.git /tmp/pip-req-build-4m60jw_7
#   Resolved https://github.com/facebookresearch/fvcore.git to commit a491d5b9a06746f387aca2f1f9c7c7f28e20bef9
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-fnvzpvak
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-fnvzpvak
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (2.0.2)
# Collecting yacs>=0.1.6 (from fvcore==0.1.6)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (4.67.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (3.0.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (11.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore==0.1.6)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (75.2.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.0.12)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from iopath>=0.1.7->fvcore==0.1.6) (4.13.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore==0.1.6)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.17.0)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Building wheels for collected packages: fvcore, pycocotools, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.6-py3-none-any.whl size=65669 sha256=7290c08b00cde509e48ef049b689cab937a3158eb6e7f8616ad22ef5ff92e3ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zvpaanvz/wheels/cb/7b/f1/170e6ac46b414a6afef30f04f353ef29c6d7b20051358b781a
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp311-cp311-linux_x86_64.whl size=395987 sha256=9d2d4730a8567364011f54e67263d58edc01ea2261c64cae85907496a1852836
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zvpaanvz/wheels/6d/69/75/358c50a37672dfda8d74ba3b30ec49fb75d52f7c081886d503
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=11034b922884cd481ccc654986a14a921de6beb32044141e99005b5bf5e2d268
#   Stored in directory: /root/.cache/pip/wheels/ba/5e/16/6117f8fe7e9c0c161a795e10d94645ebcf301ccbd01f66d8ec
# Successfully built fvcore pycocotools iopath
# Installing collected packages: yacs, portalocker, iopath, pycocotools, fvcore
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.8
#     Uninstalling pycocotools-2.0.8:
#       Successfully uninstalled pycocotools-2.0.8
# Successfully installed fvcore-0.1.6 iopath-0.1.10 portalocker-3.1.1 pycocotools-2.0 yacs-0.1.8
# '2.6.0+cu124'

# %%
# install dependencies
# !pip install -U torch torchvision cython
# !pip install -U 'git+https://github.com/facebookresearch/fvcore.git' 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
import torch, torchvision
torch.__version__
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Collecting git+https://github.com/facebookresearch/fvcore.git
#   Cloning https://github.com/facebookresearch/fvcore.git to /tmp/pip-req-build-2ahud6lk
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/fvcore.git /tmp/pip-req-build-2ahud6lk
#   Resolved https://github.com/facebookresearch/fvcore.git to commit a491d5b9a06746f387aca2f1f9c7c7f28e20bef9
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-az5qwyws
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-az5qwyws
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (2.0.2)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (0.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (4.67.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (3.0.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (11.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (0.9.0)
# Requirement already satisfied: iopath>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (0.1.10)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (75.2.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.0.12)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.10.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from iopath>=0.1.7->fvcore==0.1.6) (4.13.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from iopath>=0.1.7->fvcore==0.1.6) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.17.0)
# '2.6.0+cu124'

# %%
# !git clone https://github.com/facebookresearch/detectron2 detectron2_repo
# !pip install -e detectron2_repo
# Out:
# fatal: destination path 'detectron2_repo' already exists and is not an empty directory.
# Obtaining file:///content/detectron2_repo
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.10.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.0.1)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.18.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (25.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (4.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (3.0.2)
# Installing collected packages: detectron2
#   Attempting uninstall: detectron2
#     Found existing installation: detectron2 0.6
#     Uninstalling detectron2-0.6:
#       Successfully uninstalled detectron2-0.6
#   Running setup.py develop for detectron2
# Successfully installed detectron2-0.6

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
from collections import Counter
import matplotlib.pyplot as plt
import json
import os

# Load dataset entries
dataset_dicts = DatasetCatalog.get("car_dataset_train")
metadata = MetadataCatalog.get("car_dataset_train")

print(f"Total images: {len(dataset_dicts)}")
print(f"Metadata categories: {metadata.thing_classes}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-fdae3965c3d5> in <cell line: 0>()
#       6
#       7 # Load dataset entries
# ----> 8 dataset_dicts = DatasetCatalog.get("car_dataset_train")
#       9 metadata = MetadataCatalog.get("car_dataset_train")
#      10
#
# /content/detectron2_repo/detectron2/data/catalog.py in get(self, name)
#      56                 )
#      57             ) from e
# ---> 58         return f()
#      59
#      60     def list(self) -> List[str]:
#
# /content/detectron2_repo/detectron2/data/datasets/coco.py in <lambda>()
#     509     # 1. register a function which returns dicts
#     510     if name not in DatasetCatalog:
# --> 511         DatasetCatalog.register(name, lambda: load_coco_json(json_file, image_root, name))
#     512
#     513     # 2. Optionally, add metadata about this dataset,
#
# /content/detectron2_repo/detectron2/data/datasets/coco.py in load_coco_json(json_file, image_root, dataset_name, extra_annotation_keys)
#      83         # The categories in a custom json file may not be sorted.
#      84         thing_classes = [c["name"] for c in sorted(cats, key=lambda x: x["id"])]
# ---> 85         meta.thing_classes = thing_classes
#      86
#      87         # In COCO, certain category ids are artificially removed,
#
# /content/detectron2_repo/detectron2/data/catalog.py in __setattr__(self, key, val)
#     146         try:
#     147             oldval = getattr(self, key)
# --> 148             assert oldval == val, (
#     149                 "Attribute '{}' in the metadata of '{}' cannot be set "
#     150                 "to a different value!\n{} != {}".format(key, self.name, oldval, val)
#
# AssertionError: Attribute 'thing_classes' in the metadata of 'car_dataset_train' cannot be set to a different value!
# ['moderate-minor-severe', 'minor', 'moderate', 'severe'] != ['minor', 'moderate', 'severe']

# %%
import json

def count_classes(file_path):
    try:
        # Load the JSON file
        with open(file_path, "r") as f:
            data = json.load(f)

        # Extract class names
        if "categories" not in data:
            print("Error: No 'categories' found in the JSON file!")
            return

        categories = data["categories"]
        class_count = len(categories)
        class_names = [cat["name"] for cat in categories]

        print(f"Total classes: {class_count}")
        print("Class names:", class_names)

    except json.JSONDecodeError:
        print("Error: Invalid JSON file format!")
    except Exception as e:
        print(f"Error: {e}")

# Run the function
file_path = "/content/car_damage_dataset_coco/train/_annotations.coco.json"
count_classes(file_path)
# Out:
# Total classes: 4
# Class names: ['moderate-minor-severe', 'minor', 'moderate', 'severe']

# %%
from detectron2.config import get_cfg
from detectron2.engine import DefaultTrainer
from detectron2 import model_zoo
import os
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances

# 1. Dataset Registration (already done by you)
dataset_dir = "/content/car_damage_dataset_coco"
train_dir = "train"
val_dir = "valid"

dataset_name_train = "car_dataset_train"
dataset_name_val = "car_dataset_val"

# Unregister if exists (your existing code)
if dataset_name_train in DatasetCatalog:
    DatasetCatalog.remove(dataset_name_train)
    MetadataCatalog.remove(dataset_name_train)
if dataset_name_val in DatasetCatalog:
    DatasetCatalog.remove(dataset_name_val)
    MetadataCatalog.remove(dataset_name_val)

# Register datasets (your existing code)
register_coco_instances(
    dataset_name_train, {},
    os.path.join(dataset_dir, train_dir, "_annotations.coco.json"),
    os.path.join(dataset_dir, train_dir)
)
register_coco_instances(
    dataset_name_val, {},
    os.path.join(dataset_dir, val_dir, "_annotations.coco.json"),
    os.path.join(dataset_dir, val_dir)
)

# %%
from detectron2.config import get_cfg
from detectron2.engine import DefaultTrainer
from detectron2 import model_zoo
from detectron2.evaluation import COCOEvaluator
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances
import os

class CustomTrainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

def setup_datasets():
    # Dataset Directory
    dataset_dir = "/content/car_damage_dataset_coco"
    train_dir = "train"
    val_dir = "valid"

    dataset_name_train = "car_dataset_train"
    dataset_name_val = "car_dataset_val"

    # Unregister if exists
    for name in [dataset_name_train, dataset_name_val]:
        if name in DatasetCatalog:
            DatasetCatalog.remove(name)
            MetadataCatalog.remove(name)

    # Register datasets
    register_coco_instances(
        dataset_name_train, {},
        os.path.join(dataset_dir, train_dir, "_annotations.coco.json"),
        os.path.join(dataset_dir, train_dir)
    )
    register_coco_instances(
        dataset_name_val, {},
        os.path.join(dataset_dir, val_dir, "_annotations.coco.json"),
        os.path.join(dataset_dir, val_dir)
    )

    return dataset_name_train, dataset_name_val

def setup_config(train_dataset, val_dataset):
    cfg = get_cfg()
    cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))

    # Dataset configuration
    cfg.DATASETS.TRAIN = (train_dataset,)
    cfg.DATASETS.TEST = (val_dataset,)

    # Training parameters
    cfg.DATALOADER.NUM_WORKERS = 2
    cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
    cfg.SOLVER.IMS_PER_BATCH = 2
    cfg.SOLVER.BASE_LR = 0.0001
    cfg.SOLVER.MAX_ITER = 3000  # Increased from 300 for better convergence
    cfg.SOLVER.STEPS = [2000, 2500]
    cfg.SOLVER.CHECKPOINT_PERIOD = 500  # Save checkpoint every 500 iterations

    # Model configuration
    cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
    cfg.MODEL.ROI_HEADS.NUM_CLASSES =4   # Your number of classes

    # Evaluation configuration
    cfg.TEST.EVAL_PERIOD = 500  # Evaluate every 500 iterations
    cfg.OUTPUT_DIR = "./output"  # Output directory

    return cfg

def main():
    # Setup datasets
    train_dataset, val_dataset = setup_datasets()

    # Setup config
    cfg = setup_config(train_dataset, val_dataset)

    # Create output directory
    os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

    # Train
    trainer = CustomTrainer(cfg)
    trainer.resume_or_load(resume=False)
    trainer.train()

if __name__ == "__main__":
    main()

# %%
cfg.OUTPUT_DIR1 = "/content/output/model_final.pth"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fe2294721429> in <cell line: 0>()
# ----> 1 cfg.OUTPUT_DIR1 = "/content/output/model_final.pth"
#
# NameError: name 'cfg' is not defined

# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')

# Source and destination paths
source_path = "/content/output/model_final.pth"

destination_path = "/content/drive/My Drive/severity 3000 itr final/model_final.pth"

# Copy the model file to Google Drive
shutil.copy(source_path, destination_path)

print(f"Model saved to {destination_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model saved to /content/drive/My Drive/severity 3000 itr final/model_final.pth

# %%
from detectron2.config import get_cfg
from detectron2.engine import DefaultTrainer
from detectron2 import model_zoo
import os
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances

# Dataset Directory
dataset_dir = "/content/car_damage_dataset_coco"
train_dir = "train"
val_dir = "valid"

dataset_name_train = "car_dataset_train"
dataset_name_val = "car_dataset_val"

# Unregister if exists
if dataset_name_train in DatasetCatalog:
    DatasetCatalog.remove(dataset_name_train)
    MetadataCatalog.remove(dataset_name_train)
if dataset_name_val in DatasetCatalog:
    DatasetCatalog.remove(dataset_name_val)
    MetadataCatalog.remove(dataset_name_val)

# Register datasets
register_coco_instances(
    dataset_name_train, {},
    os.path.join(dataset_dir, train_dir, "_annotations.coco.json"),
    os.path.join(dataset_dir, train_dir)
)
register_coco_instances(
    dataset_name_val, {},
    os.path.join(dataset_dir, val_dir, "_annotations.coco.json"),
    os.path.join(dataset_dir, val_dir)
)

# Load Detectron2 Config
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("car_dataset_train",)
cfg.DATASETS.TEST = ("car_dataset_val",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 300
cfg.SOLVER.STEPS = []
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 4

# Training
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()

# %%
from detectron2.config import get_cfg
from detectron2.engine import DefaultTrainer
from detectron2 import model_zoo
from detectron2.data.datasets import register_coco_instances
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.evaluation import COCOEvaluator
import os

# Paths
dataset_dir = "/content/car_damage_dataset_coco"
train_dir = "train"
val_dir = "valid"

# Dataset names
dataset_name_train = "car_dataset_train"
dataset_name_val = "car_dataset_val"

# Re-register dataset
for name in [dataset_name_train, dataset_name_val]:
    if name in DatasetCatalog:
        DatasetCatalog.remove(name)
        MetadataCatalog.remove(name)

register_coco_instances(
    dataset_name_train, {},
    os.path.join(dataset_dir, train_dir, "_annotations.coco.json"),
    os.path.join(dataset_dir, train_dir)
)
register_coco_instances(
    dataset_name_val, {},
    os.path.join(dataset_dir, val_dir, "_annotations.coco.json"),
    os.path.join(dataset_dir, val_dir)
)

# ⚙️ Custom Trainer with Evaluator
from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "eval")
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

# Config setup
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")

cfg.DATASETS.TRAIN = (dataset_name_train,)
cfg.DATASETS.TEST = (dataset_name_val,)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.SOLVER.IMS_PER_BATCH = 2

# 🔧 TRAINING LENGTH
cfg.SOLVER.MAX_ITER = 3000  # way more than 300
cfg.SOLVER.STEPS = [2000, 2600]  # LR decays
cfg.SOLVER.GAMMA = 0.1

# 🔧 OPTIMIZATION
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.CHECKPOINT_PERIOD = 500
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3  # ✅ corrected from 4 -> 3

# 🔧 OUTPUT
cfg.OUTPUT_DIR = "./output"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# Train
trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [04/05 13:22:04 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# WARNING [04/05 13:22:04 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/05 13:22:04 d2.data.datasets.coco]: Loaded 120 images in COCO format from /content/car_damage_dataset_coco/train/_annotations.coco.json
# [04/05 13:22:04 d2.data.build]: Removed 1 images with no usable annotations. 119 images left.
# [04/05 13:22:04 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [04/05 13:22:04 d2.data.build]: Using training sampler TrainingSampler
# [04/05 13:22:04 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/05 13:22:04 d2.data.common]: Serializing 119 elements to byte tensors and concatenating them all ...
# [04/05 13:22:04 d2.data.common]: Serialized dataset takes 0.09 MiB
# [04/05 13:22:04 d2.data.build]: Making batched data loader with batch_size=2
# [04/05 13:22:04 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (12, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (12,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (3, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [04/05 13:22:04 d2.engine.train_loop]: Starting training from iteration 0
# [04/05 13:22:11 d2.utils.events]:  eta: 0:17:54  iter: 19  total_loss: 2.386  loss_cls: 1.231  loss_box_reg: 0.4063  loss_mask: 0.6922  loss_rpn_cls: 0.02431  loss_rpn_loc: 0.009173    time: 0.3503  last_time: 0.2842  data_time: 0.0182  last_data_time: 0.0050   lr: 4.9953e-06  max_mem: 2959M
# [04/05 13:22:18 d2.utils.events]:  eta: 0:16:41  iter: 39  total_loss: 2.338  loss_cls: 1.138  loss_box_reg: 0.443  loss_mask: 0.6897  loss_rpn_cls: 0.01445  loss_rpn_loc: 0.01096    time: 0.3403  last_time: 0.3813  data_time: 0.0076  last_data_time: 0.0119   lr: 9.9902e-06  max_mem: 2959M
# [04/05 13:22:25 d2.utils.events]:  eta: 0:16:36  iter: 59  total_loss: 2.079  loss_cls: 0.9784  loss_box_reg: 0.3814  loss_mask: 0.6821  loss_rpn_cls: 0.01642  loss_rpn_loc: 0.008178    time: 0.3416  last_time: 0.3322  data_time: 0.0098  last_data_time: 0.0064   lr: 1.4985e-05  max_mem: 2959M
# [04/05 13:22:32 d2.utils.events]:  eta: 0:16:39  iter: 79  total_loss: 1.774  loss_cls: 0.7544  loss_box_reg: 0.3127  loss_mask: 0.6759  loss_rpn_cls: 0.02077  loss_rpn_loc: 0.008565    time: 0.3433  last_time: 0.3246  data_time: 0.0073  last_data_time: 0.0144   lr: 1.998e-05  max_mem: 2959M
# [04/05 13:22:39 d2.utils.events]:  eta: 0:16:37  iter: 99  total_loss: 1.65  loss_cls: 0.5881  loss_box_reg: 0.4244  loss_mask: 0.6647  loss_rpn_cls: 0.01597  loss_rpn_loc: 0.01181    time: 0.3450  last_time: 0.3552  data_time: 0.0098  last_data_time: 0.0053   lr: 2.4975e-05  max_mem: 2959M
# [04/05 13:22:46 d2.utils.events]:  eta: 0:16:36  iter: 119  total_loss: 1.668  loss_cls: 0.5173  loss_box_reg: 0.4544  loss_mask: 0.6597  loss_rpn_cls: 0.01862  loss_rpn_loc: 0.009225    time: 0.3463  last_time: 0.3868  data_time: 0.0076  last_data_time: 0.0053   lr: 2.997e-05  max_mem: 2959M
# [04/05 13:22:53 d2.utils.events]:  eta: 0:16:29  iter: 139  total_loss: 1.536  loss_cls: 0.4586  loss_box_reg: 0.4374  loss_mask: 0.6424  loss_rpn_cls: 0.01916  loss_rpn_loc: 0.009378    time: 0.3458  last_time: 0.3708  data_time: 0.0120  last_data_time: 0.0050   lr: 3.4965e-05  max_mem: 2959M
# [04/05 13:22:59 d2.utils.events]:  eta: 0:16:10  iter: 159  total_loss: 1.47  loss_cls: 0.3852  loss_box_reg: 0.3724  loss_mask: 0.6427  loss_rpn_cls: 0.0174  loss_rpn_loc: 0.008027    time: 0.3424  last_time: 0.3018  data_time: 0.0079  last_data_time: 0.0051   lr: 3.996e-05  max_mem: 2959M
# [04/05 13:23:06 d2.utils.events]:  eta: 0:16:05  iter: 179  total_loss: 1.427  loss_cls: 0.3811  loss_box_reg: 0.4193  loss_mask: 0.6214  loss_rpn_cls: 0.01996  loss_rpn_loc: 0.00835    time: 0.3431  last_time: 0.3369  data_time: 0.0111  last_data_time: 0.0115   lr: 4.4955e-05  max_mem: 2959M
# [04/05 13:23:13 d2.utils.events]:  eta: 0:15:56  iter: 199  total_loss: 1.515  loss_cls: 0.3756  loss_box_reg: 0.4374  loss_mask: 0.6155  loss_rpn_cls: 0.01535  loss_rpn_loc: 0.009188    time: 0.3418  last_time: 0.3691  data_time: 0.0067  last_data_time: 0.0050   lr: 4.995e-05  max_mem: 2959M
# [04/05 13:23:20 d2.utils.events]:  eta: 0:15:49  iter: 219  total_loss: 1.346  loss_cls: 0.3108  loss_box_reg: 0.37  loss_mask: 0.6106  loss_rpn_cls: 0.02064  loss_rpn_loc: 0.008837    time: 0.3414  last_time: 0.2900  data_time: 0.0132  last_data_time: 0.0135   lr: 5.4945e-05  max_mem: 2959M
# [04/05 13:23:26 d2.utils.events]:  eta: 0:15:40  iter: 239  total_loss: 1.437  loss_cls: 0.3303  loss_box_reg: 0.5093  loss_mask: 0.5821  loss_rpn_cls: 0.01237  loss_rpn_loc: 0.008561    time: 0.3403  last_time: 0.3466  data_time: 0.0082  last_data_time: 0.0174   lr: 5.994e-05  max_mem: 2959M
# [04/05 13:23:33 d2.utils.events]:  eta: 0:15:36  iter: 259  total_loss: 1.423  loss_cls: 0.33  loss_box_reg: 0.4457  loss_mask: 0.5694  loss_rpn_cls: 0.01442  loss_rpn_loc: 0.00785    time: 0.3413  last_time: 0.3854  data_time: 0.0129  last_data_time: 0.0122   lr: 6.4935e-05  max_mem: 2959M
# [04/05 13:23:40 d2.utils.events]:  eta: 0:15:29  iter: 279  total_loss: 1.358  loss_cls: 0.3176  loss_box_reg: 0.4738  loss_mask: 0.5407  loss_rpn_cls: 0.008094  loss_rpn_loc: 0.008616    time: 0.3415  last_time: 0.3626  data_time: 0.0056  last_data_time: 0.0053   lr: 6.993e-05  max_mem: 2959M
# [04/05 13:23:47 d2.utils.events]:  eta: 0:15:23  iter: 299  total_loss: 1.26  loss_cls: 0.2773  loss_box_reg: 0.4109  loss_mask: 0.5489  loss_rpn_cls: 0.01487  loss_rpn_loc: 0.006698    time: 0.3420  last_time: 0.3085  data_time: 0.0119  last_data_time: 0.0051   lr: 7.4925e-05  max_mem: 2959M
# [04/05 13:23:54 d2.utils.events]:  eta: 0:15:14  iter: 319  total_loss: 1.245  loss_cls: 0.2667  loss_box_reg: 0.3485  loss_mask: 0.5451  loss_rpn_cls: 0.02265  loss_rpn_loc: 0.008309    time: 0.3418  last_time: 0.3820  data_time: 0.0065  last_data_time: 0.0050   lr: 7.992e-05  max_mem: 2959M
# [04/05 13:24:02 d2.utils.events]:  eta: 0:15:09  iter: 339  total_loss: 1.494  loss_cls: 0.3406  loss_box_reg: 0.5196  loss_mask: 0.5713  loss_rpn_cls: 0.01066  loss_rpn_loc: 0.008527    time: 0.3441  last_time: 0.3374  data_time: 0.0200  last_data_time: 0.0113   lr: 8.4915e-05  max_mem: 2959M
# [04/05 13:24:08 d2.utils.events]:  eta: 0:14:59  iter: 359  total_loss: 1.211  loss_cls: 0.2664  loss_box_reg: 0.4109  loss_mask: 0.5444  loss_rpn_cls: 0.01374  loss_rpn_loc: 0.008336    time: 0.3430  last_time: 0.3746  data_time: 0.0073  last_data_time: 0.0051   lr: 8.991e-05  max_mem: 2959M
# [04/05 13:24:15 d2.utils.events]:  eta: 0:14:52  iter: 379  total_loss: 1.223  loss_cls: 0.2711  loss_box_reg: 0.3997  loss_mask: 0.5508  loss_rpn_cls: 0.01147  loss_rpn_loc: 0.006172    time: 0.3431  last_time: 0.3397  data_time: 0.0101  last_data_time: 0.0050   lr: 9.4905e-05  max_mem: 2959M
# [04/05 13:24:22 d2.utils.events]:  eta: 0:14:48  iter: 399  total_loss: 1.491  loss_cls: 0.2999  loss_box_reg: 0.4707  loss_mask: 0.5428  loss_rpn_cls: 0.01496  loss_rpn_loc: 0.008709    time: 0.3434  last_time: 0.3416  data_time: 0.0083  last_data_time: 0.0126   lr: 9.99e-05  max_mem: 2959M
# [04/05 13:24:29 d2.utils.events]:  eta: 0:14:41  iter: 419  total_loss: 1.267  loss_cls: 0.2963  loss_box_reg: 0.4424  loss_mask: 0.5597  loss_rpn_cls: 0.007807  loss_rpn_loc: 0.006548    time: 0.3438  last_time: 0.3384  data_time: 0.0130  last_data_time: 0.0055   lr: 0.0001049  max_mem: 2959M
# [04/05 13:24:36 d2.utils.events]:  eta: 0:14:35  iter: 439  total_loss: 1.26  loss_cls: 0.2521  loss_box_reg: 0.3863  loss_mask: 0.5483  loss_rpn_cls: 0.004898  loss_rpn_loc: 0.0083    time: 0.3436  last_time: 0.3482  data_time: 0.0081  last_data_time: 0.0119   lr: 0.00010989  max_mem: 2959M
# [04/05 13:24:43 d2.utils.events]:  eta: 0:14:29  iter: 459  total_loss: 1.236  loss_cls: 0.2823  loss_box_reg: 0.4337  loss_mask: 0.5273  loss_rpn_cls: 0.008412  loss_rpn_loc: 0.00686    time: 0.3435  last_time: 0.3006  data_time: 0.0112  last_data_time: 0.0056   lr: 0.00011489  max_mem: 2959M
# [04/05 13:24:49 d2.utils.events]:  eta: 0:14:22  iter: 479  total_loss: 1.317  loss_cls: 0.2995  loss_box_reg: 0.4466  loss_mask: 0.5115  loss_rpn_cls: 0.01177  loss_rpn_loc: 0.006936    time: 0.3433  last_time: 0.3395  data_time: 0.0104  last_data_time: 0.0172   lr: 0.00011988  max_mem: 2959M
# [04/05 13:24:58 d2.utils.events]:  eta: 0:14:14  iter: 499  total_loss: 1.147  loss_cls: 0.2443  loss_box_reg: 0.4085  loss_mask: 0.5013  loss_rpn_cls: 0.01405  loss_rpn_loc: 0.006587    time: 0.3429  last_time: 0.3293  data_time: 0.0080  last_data_time: 0.0168   lr: 0.00012488  max_mem: 2959M
# [04/05 13:25:05 d2.utils.events]:  eta: 0:14:07  iter: 519  total_loss: 1.228  loss_cls: 0.2435  loss_box_reg: 0.4654  loss_mask: 0.4932  loss_rpn_cls: 0.004341  loss_rpn_loc: 0.007083    time: 0.3431  last_time: 0.3826  data_time: 0.0118  last_data_time: 0.0240   lr: 0.00012987  max_mem: 2959M
# [04/05 13:25:12 d2.utils.events]:  eta: 0:14:00  iter: 539  total_loss: 1.159  loss_cls: 0.2629  loss_box_reg: 0.3542  loss_mask: 0.5154  loss_rpn_cls: 0.005558  loss_rpn_loc: 0.005872    time: 0.3430  last_time: 0.2994  data_time: 0.0079  last_data_time: 0.0134   lr: 0.00013487  max_mem: 2959M
# [04/05 13:25:19 d2.utils.events]:  eta: 0:13:54  iter: 559  total_loss: 1.341  loss_cls: 0.2904  loss_box_reg: 0.4842  loss_mask: 0.5484  loss_rpn_cls: 0.006922  loss_rpn_loc: 0.007876    time: 0.3433  last_time: 0.3946  data_time: 0.0122  last_data_time: 0.0053   lr: 0.00013986  max_mem: 2959M
# [04/05 13:25:26 d2.utils.events]:  eta: 0:13:48  iter: 579  total_loss: 1.212  loss_cls: 0.2576  loss_box_reg: 0.4171  loss_mask: 0.4837  loss_rpn_cls: 0.008967  loss_rpn_loc: 0.007411    time: 0.3434  last_time: 0.3450  data_time: 0.0076  last_data_time: 0.0257   lr: 0.00014486  max_mem: 2959M
# [04/05 13:25:32 d2.utils.events]:  eta: 0:13:41  iter: 599  total_loss: 1.11  loss_cls: 0.2348  loss_box_reg: 0.3782  loss_mask: 0.4409  loss_rpn_cls: 0.007874  loss_rpn_loc: 0.006766    time: 0.3434  last_time: 0.2983  data_time: 0.0118  last_data_time: 0.0153   lr: 0.00014985  max_mem: 2959M
# [04/05 13:25:39 d2.utils.events]:  eta: 0:13:33  iter: 619  total_loss: 1.08  loss_cls: 0.2295  loss_box_reg: 0.3222  loss_mask: 0.4684  loss_rpn_cls: 0.007485  loss_rpn_loc: 0.006675    time: 0.3433  last_time: 0.3565  data_time: 0.0077  last_data_time: 0.0121   lr: 0.00015485  max_mem: 2959M
# [04/05 13:25:46 d2.utils.events]:  eta: 0:13:28  iter: 639  total_loss: 1.192  loss_cls: 0.2487  loss_box_reg: 0.4439  loss_mask: 0.4764  loss_rpn_cls: 0.01387  loss_rpn_loc: 0.006212    time: 0.3436  last_time: 0.3502  data_time: 0.0122  last_data_time: 0.0055   lr: 0.00015984  max_mem: 2959M
# [04/05 13:25:53 d2.utils.events]:  eta: 0:13:19  iter: 659  total_loss: 1.103  loss_cls: 0.2571  loss_box_reg: 0.3808  loss_mask: 0.4356  loss_rpn_cls: 0.00499  loss_rpn_loc: 0.006363    time: 0.3430  last_time: 0.3420  data_time: 0.0082  last_data_time: 0.0049   lr: 0.00016484  max_mem: 2959M
# [04/05 13:26:00 d2.utils.events]:  eta: 0:13:13  iter: 679  total_loss: 1.104  loss_cls: 0.2448  loss_box_reg: 0.3641  loss_mask: 0.413  loss_rpn_cls: 0.005975  loss_rpn_loc: 0.006343    time: 0.3435  last_time: 0.3195  data_time: 0.0124  last_data_time: 0.0045   lr: 0.00016983  max_mem: 2959M
# [04/05 13:26:07 d2.utils.events]:  eta: 0:13:06  iter: 699  total_loss: 1.208  loss_cls: 0.2265  loss_box_reg: 0.444  loss_mask: 0.486  loss_rpn_cls: 0.008807  loss_rpn_loc: 0.006775    time: 0.3433  last_time: 0.3501  data_time: 0.0075  last_data_time: 0.0047   lr: 0.00017483  max_mem: 2959M
# [04/05 13:26:14 d2.utils.events]:  eta: 0:13:00  iter: 719  total_loss: 1.039  loss_cls: 0.2175  loss_box_reg: 0.3411  loss_mask: 0.4818  loss_rpn_cls: 0.00753  loss_rpn_loc: 0.006994    time: 0.3434  last_time: 0.3008  data_time: 0.0110  last_data_time: 0.0051   lr: 0.00017982  max_mem: 2959M
# [04/05 13:26:21 d2.utils.events]:  eta: 0:12:53  iter: 739  total_loss: 1.201  loss_cls: 0.2502  loss_box_reg: 0.4219  loss_mask: 0.4577  loss_rpn_cls: 0.008639  loss_rpn_loc: 0.005803    time: 0.3433  last_time: 0.3372  data_time: 0.0080  last_data_time: 0.0048   lr: 0.00018482  max_mem: 2959M
# [04/05 13:26:28 d2.utils.events]:  eta: 0:12:47  iter: 759  total_loss: 1.046  loss_cls: 0.1817  loss_box_reg: 0.3567  loss_mask: 0.4487  loss_rpn_cls: 0.004187  loss_rpn_loc: 0.006244    time: 0.3436  last_time: 0.3392  data_time: 0.0135  last_data_time: 0.0063   lr: 0.00018981  max_mem: 2959M
# [04/05 13:26:34 d2.utils.events]:  eta: 0:12:39  iter: 779  total_loss: 1.066  loss_cls: 0.1987  loss_box_reg: 0.3708  loss_mask: 0.44  loss_rpn_cls: 0.007895  loss_rpn_loc: 0.005315    time: 0.3432  last_time: 0.3377  data_time: 0.0074  last_data_time: 0.0051   lr: 0.00019481  max_mem: 2959M
# [04/05 13:26:41 d2.utils.events]:  eta: 0:12:33  iter: 799  total_loss: 0.9923  loss_cls: 0.193  loss_box_reg: 0.3848  loss_mask: 0.4095  loss_rpn_cls: 0.004485  loss_rpn_loc: 0.005662    time: 0.3433  last_time: 0.3019  data_time: 0.0104  last_data_time: 0.0050   lr: 0.0001998  max_mem: 2959M
# [04/05 13:26:48 d2.utils.events]:  eta: 0:12:26  iter: 819  total_loss: 1.108  loss_cls: 0.228  loss_box_reg: 0.3966  loss_mask: 0.4649  loss_rpn_cls: 0.008107  loss_rpn_loc: 0.006354    time: 0.3431  last_time: 0.2972  data_time: 0.0103  last_data_time: 0.0050   lr: 0.0002048  max_mem: 2959M
# [04/05 13:26:55 d2.utils.events]:  eta: 0:12:19  iter: 839  total_loss: 0.942  loss_cls: 0.1466  loss_box_reg: 0.3091  loss_mask: 0.434  loss_rpn_cls: 0.005281  loss_rpn_loc: 0.008393    time: 0.3434  last_time: 0.3710  data_time: 0.0120  last_data_time: 0.0050   lr: 0.00020979  max_mem: 2959M
# [04/05 13:27:02 d2.utils.events]:  eta: 0:12:12  iter: 859  total_loss: 1.014  loss_cls: 0.1861  loss_box_reg: 0.3473  loss_mask: 0.3972  loss_rpn_cls: 0.003888  loss_rpn_loc: 0.005475    time: 0.3431  last_time: 0.3232  data_time: 0.0092  last_data_time: 0.0114   lr: 0.00021479  max_mem: 2959M
# [04/05 13:27:09 d2.utils.events]:  eta: 0:12:06  iter: 879  total_loss: 1.043  loss_cls: 0.2122  loss_box_reg: 0.3938  loss_mask: 0.3839  loss_rpn_cls: 0.005182  loss_rpn_loc: 0.006321    time: 0.3434  last_time: 0.3816  data_time: 0.0133  last_data_time: 0.0119   lr: 0.00021978  max_mem: 2959M
# [04/05 13:27:16 d2.utils.events]:  eta: 0:11:59  iter: 899  total_loss: 0.9083  loss_cls: 0.183  loss_box_reg: 0.3141  loss_mask: 0.385  loss_rpn_cls: 0.00214  loss_rpn_loc: 0.006615    time: 0.3434  last_time: 0.3979  data_time: 0.0095  last_data_time: 0.0186   lr: 0.00022478  max_mem: 2959M
# [04/05 13:27:22 d2.utils.events]:  eta: 0:11:52  iter: 919  total_loss: 1.045  loss_cls: 0.2211  loss_box_reg: 0.3815  loss_mask: 0.3968  loss_rpn_cls: 0.002018  loss_rpn_loc: 0.004901    time: 0.3433  last_time: 0.3404  data_time: 0.0088  last_data_time: 0.0050   lr: 0.00022977  max_mem: 2959M
# [04/05 13:27:29 d2.utils.events]:  eta: 0:11:45  iter: 939  total_loss: 0.9246  loss_cls: 0.1863  loss_box_reg: 0.3314  loss_mask: 0.3553  loss_rpn_cls: 0.003729  loss_rpn_loc: 0.006085    time: 0.3432  last_time: 0.3679  data_time: 0.0060  last_data_time: 0.0163   lr: 0.00023477  max_mem: 2959M
# [04/05 13:27:36 d2.utils.events]:  eta: 0:11:38  iter: 959  total_loss: 0.9314  loss_cls: 0.2089  loss_box_reg: 0.3678  loss_mask: 0.3602  loss_rpn_cls: 0.004521  loss_rpn_loc: 0.005089    time: 0.3432  last_time: 0.3837  data_time: 0.0084  last_data_time: 0.0049   lr: 0.00023976  max_mem: 2959M
# [04/05 13:27:43 d2.utils.events]:  eta: 0:11:30  iter: 979  total_loss: 0.8271  loss_cls: 0.178  loss_box_reg: 0.2979  loss_mask: 0.3323  loss_rpn_cls: 0.001641  loss_rpn_loc: 0.005863    time: 0.3430  last_time: 0.3305  data_time: 0.0082  last_data_time: 0.0178   lr: 0.00024476  max_mem: 2959M
# [04/05 13:27:51 d2.utils.events]:  eta: 0:11:23  iter: 999  total_loss: 0.8514  loss_cls: 0.1691  loss_box_reg: 0.3249  loss_mask: 0.3517  loss_rpn_cls: 0.003558  loss_rpn_loc: 0.004789    time: 0.3430  last_time: 0.2857  data_time: 0.0125  last_data_time: 0.0117   lr: 0.00024975  max_mem: 2959M
# [04/05 13:27:59 d2.utils.events]:  eta: 0:11:17  iter: 1019  total_loss: 0.967  loss_cls: 0.2095  loss_box_reg: 0.3723  loss_mask: 0.3542  loss_rpn_cls: 0.004929  loss_rpn_loc: 0.004445    time: 0.3434  last_time: 0.3906  data_time: 0.0098  last_data_time: 0.0054   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:06 d2.utils.events]:  eta: 0:11:11  iter: 1039  total_loss: 0.812  loss_cls: 0.1256  loss_box_reg: 0.3365  loss_mask: 0.3353  loss_rpn_cls: 0.003015  loss_rpn_loc: 0.005765    time: 0.3434  last_time: 0.3123  data_time: 0.0065  last_data_time: 0.0049   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:13 d2.utils.events]:  eta: 0:11:05  iter: 1059  total_loss: 0.8768  loss_cls: 0.1904  loss_box_reg: 0.296  loss_mask: 0.3351  loss_rpn_cls: 0.001803  loss_rpn_loc: 0.006482    time: 0.3437  last_time: 0.3729  data_time: 0.0118  last_data_time: 0.0052   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:20 d2.utils.events]:  eta: 0:10:59  iter: 1079  total_loss: 0.9234  loss_cls: 0.1574  loss_box_reg: 0.3346  loss_mask: 0.3533  loss_rpn_cls: 0.002421  loss_rpn_loc: 0.00528    time: 0.3439  last_time: 0.3436  data_time: 0.0072  last_data_time: 0.0125   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:27 d2.utils.events]:  eta: 0:10:51  iter: 1099  total_loss: 0.8217  loss_cls: 0.1682  loss_box_reg: 0.3055  loss_mask: 0.3205  loss_rpn_cls: 0.001276  loss_rpn_loc: 0.003982    time: 0.3440  last_time: 0.3372  data_time: 0.0135  last_data_time: 0.0052   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:34 d2.utils.events]:  eta: 0:10:45  iter: 1119  total_loss: 0.8597  loss_cls: 0.1519  loss_box_reg: 0.31  loss_mask: 0.3106  loss_rpn_cls: 0.001351  loss_rpn_loc: 0.00418    time: 0.3440  last_time: 0.3900  data_time: 0.0090  last_data_time: 0.0175   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:41 d2.utils.events]:  eta: 0:10:38  iter: 1139  total_loss: 0.7996  loss_cls: 0.1448  loss_box_reg: 0.3275  loss_mask: 0.3156  loss_rpn_cls: 0.002043  loss_rpn_loc: 0.004976    time: 0.3442  last_time: 0.3839  data_time: 0.0091  last_data_time: 0.0049   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:48 d2.utils.events]:  eta: 0:10:32  iter: 1159  total_loss: 0.7887  loss_cls: 0.1342  loss_box_reg: 0.3358  loss_mask: 0.2942  loss_rpn_cls: 0.00057  loss_rpn_loc: 0.005122    time: 0.3442  last_time: 0.3656  data_time: 0.0071  last_data_time: 0.0050   lr: 0.00025  max_mem: 2959M
# [04/05 13:28:55 d2.utils.events]:  eta: 0:10:25  iter: 1179  total_loss: 0.7588  loss_cls: 0.1356  loss_box_reg: 0.2554  loss_mask: 0.3134  loss_rpn_cls: 0.002045  loss_rpn_loc: 0.004568    time: 0.3441  last_time: 0.3515  data_time: 0.0142  last_data_time: 0.0116   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:02 d2.utils.events]:  eta: 0:10:19  iter: 1199  total_loss: 0.7049  loss_cls: 0.1338  loss_box_reg: 0.2805  loss_mask: 0.2846  loss_rpn_cls: 0.002808  loss_rpn_loc: 0.005759    time: 0.3443  last_time: 0.3529  data_time: 0.0106  last_data_time: 0.0121   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:09 d2.utils.events]:  eta: 0:10:13  iter: 1219  total_loss: 0.8345  loss_cls: 0.1534  loss_box_reg: 0.3537  loss_mask: 0.3088  loss_rpn_cls: 0.002081  loss_rpn_loc: 0.005358    time: 0.3446  last_time: 0.3482  data_time: 0.0118  last_data_time: 0.0054   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:16 d2.utils.events]:  eta: 0:10:06  iter: 1239  total_loss: 0.639  loss_cls: 0.1081  loss_box_reg: 0.2302  loss_mask: 0.29  loss_rpn_cls: 0.0007225  loss_rpn_loc: 0.004097    time: 0.3445  last_time: 0.3600  data_time: 0.0074  last_data_time: 0.0129   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:23 d2.utils.events]:  eta: 0:09:59  iter: 1259  total_loss: 0.6242  loss_cls: 0.1008  loss_box_reg: 0.2414  loss_mask: 0.2686  loss_rpn_cls: 0.001663  loss_rpn_loc: 0.004021    time: 0.3445  last_time: 0.3791  data_time: 0.0091  last_data_time: 0.0047   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:30 d2.utils.events]:  eta: 0:09:53  iter: 1279  total_loss: 0.5911  loss_cls: 0.08885  loss_box_reg: 0.209  loss_mask: 0.2439  loss_rpn_cls: 0.0005037  loss_rpn_loc: 0.004388    time: 0.3447  last_time: 0.4091  data_time: 0.0103  last_data_time: 0.0134   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:37 d2.utils.events]:  eta: 0:09:46  iter: 1299  total_loss: 0.7711  loss_cls: 0.1186  loss_box_reg: 0.2605  loss_mask: 0.291  loss_rpn_cls: 0.0009884  loss_rpn_loc: 0.005818    time: 0.3447  last_time: 0.3453  data_time: 0.0083  last_data_time: 0.0053   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:44 d2.utils.events]:  eta: 0:09:40  iter: 1319  total_loss: 0.6363  loss_cls: 0.11  loss_box_reg: 0.2415  loss_mask: 0.2702  loss_rpn_cls: 0.0008954  loss_rpn_loc: 0.005453    time: 0.3450  last_time: 0.3918  data_time: 0.0095  last_data_time: 0.0175   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:52 d2.utils.events]:  eta: 0:09:33  iter: 1339  total_loss: 0.642  loss_cls: 0.1127  loss_box_reg: 0.2417  loss_mask: 0.2919  loss_rpn_cls: 0.002692  loss_rpn_loc: 0.004266    time: 0.3452  last_time: 0.3563  data_time: 0.0077  last_data_time: 0.0058   lr: 0.00025  max_mem: 2959M
# [04/05 13:29:59 d2.utils.events]:  eta: 0:09:27  iter: 1359  total_loss: 0.5965  loss_cls: 0.1099  loss_box_reg: 0.2337  loss_mask: 0.2571  loss_rpn_cls: 0.001245  loss_rpn_loc: 0.004928    time: 0.3455  last_time: 0.3391  data_time: 0.0124  last_data_time: 0.0129   lr: 0.00025  max_mem: 2959M
# [04/05 13:30:06 d2.utils.events]:  eta: 0:09:20  iter: 1379  total_loss: 0.5776  loss_cls: 0.08804  loss_box_reg: 0.2203  loss_mask: 0.2644  loss_rpn_cls: 0.001052  loss_rpn_loc: 0.004802    time: 0.3454  last_time: 0.3841  data_time: 0.0079  last_data_time: 0.0065   lr: 0.00025  max_mem: 2959M
# [04/05 13:30:13 d2.utils.events]:  eta: 0:09:14  iter: 1399  total_loss: 0.5679  loss_cls: 0.1005  loss_box_reg: 0.2231  loss_mask: 0.2425  loss_rpn_cls: 0.001369  loss_rpn_loc: 0.004393    time: 0.3456  last_time: 0.3985  data_time: 0.0124  last_data_time: 0.0051   lr: 0.00025  max_mem: 2959M
# [04/05 13:30:20 d2.utils.events]:  eta: 0:09:06  iter: 1419  total_loss: 0.571  loss_cls: 0.09462  loss_box_reg: 0.2216  loss_mask: 0.248  loss_rpn_cls: 0.001511  loss_rpn_loc: 0.004662    time: 0.3455  last_time: 0.3395  data_time: 0.0065  last_data_time: 0.0114   lr: 0.00025  max_mem: 2959M
# [04/05 13:30:27 d2.utils.events]:  eta: 0:09:00  iter: 1439  total_loss: 0.5882  loss_cls: 0.09191  loss_box_reg: 0.2436  loss_mask: 0.2393  loss_rpn_cls: 0.0008163  loss_rpn_loc: 0.005345    time: 0.3457  last_time: 0.3817  data_time: 0.0082  last_data_time: 0.0049   lr: 0.00025  max_mem: 2959M
# [04/05 13:30:34 d2.utils.events]:  eta: 0:08:52  iter: 1459  total_loss: 0.5894  loss_cls: 0.08615  loss_box_reg: 0.2605  loss_mask: 0.2595  loss_rpn_cls: 0.001472  loss_rpn_loc: 0.005092    time: 0.3456  last_time: 0.3015  data_time: 0.0068  last_data_time: 0.0053   lr: 0.00025  max_mem: 2959M
# [04/05 13:30:41 d2.utils.events]:  eta: 0:08:46  iter: 1479  total_loss: 0.6232  loss_cls: 0.106  loss_box_reg: 0.2352  loss_mask: 0.2482  loss_rpn_cls: 0.0007073  loss_rpn_loc: 0.005107    time: 0.3457  last_time: 0.3582  data_time: 0.0131  last_data_time: 0.0118   lr: 0.00025  max_mem: 2959M
# [04/05 13:30:53 d2.utils.events]:  eta: 0:08:39  iter: 1499  total_loss: 0.5649  loss_cls: 0.0798  loss_box_reg: 0.2529  loss_mask: 0.2347  loss_rpn_cls: 0.00163  loss_rpn_loc: 0.005114    time: 0.3458  last_time: 0.3487  data_time: 0.0072  last_data_time: 0.0050   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:00 d2.utils.events]:  eta: 0:08:32  iter: 1519  total_loss: 0.5964  loss_cls: 0.09953  loss_box_reg: 0.2475  loss_mask: 0.2644  loss_rpn_cls: 0.0008725  loss_rpn_loc: 0.003992    time: 0.3458  last_time: 0.3184  data_time: 0.0087  last_data_time: 0.0050   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:07 d2.utils.events]:  eta: 0:08:25  iter: 1539  total_loss: 0.6366  loss_cls: 0.07878  loss_box_reg: 0.2104  loss_mask: 0.2601  loss_rpn_cls: 0.0007479  loss_rpn_loc: 0.004473    time: 0.3459  last_time: 0.3163  data_time: 0.0107  last_data_time: 0.0046   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:14 d2.utils.events]:  eta: 0:08:18  iter: 1559  total_loss: 0.5854  loss_cls: 0.07762  loss_box_reg: 0.1971  loss_mask: 0.2418  loss_rpn_cls: 0.001721  loss_rpn_loc: 0.003823    time: 0.3458  last_time: 0.3442  data_time: 0.0081  last_data_time: 0.0046   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:21 d2.utils.events]:  eta: 0:08:11  iter: 1579  total_loss: 0.5107  loss_cls: 0.07194  loss_box_reg: 0.2277  loss_mask: 0.1904  loss_rpn_cls: 0.0005177  loss_rpn_loc: 0.004508    time: 0.3458  last_time: 0.3626  data_time: 0.0105  last_data_time: 0.0049   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:28 d2.utils.events]:  eta: 0:08:04  iter: 1599  total_loss: 0.5322  loss_cls: 0.07923  loss_box_reg: 0.2024  loss_mask: 0.2292  loss_rpn_cls: 0.0007239  loss_rpn_loc: 0.004628    time: 0.3458  last_time: 0.4090  data_time: 0.0091  last_data_time: 0.0101   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:36 d2.utils.events]:  eta: 0:07:58  iter: 1619  total_loss: 0.5327  loss_cls: 0.06336  loss_box_reg: 0.1912  loss_mask: 0.213  loss_rpn_cls: 0.0008654  loss_rpn_loc: 0.00382    time: 0.3464  last_time: 0.2969  data_time: 0.0151  last_data_time: 0.0049   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:43 d2.utils.events]:  eta: 0:07:51  iter: 1639  total_loss: 0.5257  loss_cls: 0.07172  loss_box_reg: 0.2232  loss_mask: 0.2382  loss_rpn_cls: 0.0003273  loss_rpn_loc: 0.005055    time: 0.3466  last_time: 0.4223  data_time: 0.0094  last_data_time: 0.0208   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:50 d2.utils.events]:  eta: 0:07:45  iter: 1659  total_loss: 0.4584  loss_cls: 0.0589  loss_box_reg: 0.1858  loss_mask: 0.1882  loss_rpn_cls: 0.001535  loss_rpn_loc: 0.003691    time: 0.3465  last_time: 0.3044  data_time: 0.0099  last_data_time: 0.0050   lr: 0.00025  max_mem: 2959M
# [04/05 13:31:57 d2.utils.events]:  eta: 0:07:38  iter: 1679  total_loss: 0.5325  loss_cls: 0.08313  loss_box_reg: 0.2154  loss_mask: 0.2214  loss_rpn_cls: 0.0005558  loss_rpn_loc: 0.004434    time: 0.3467  last_time: 0.3800  data_time: 0.0105  last_data_time: 0.0348   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:04 d2.utils.events]:  eta: 0:07:31  iter: 1699  total_loss: 0.4587  loss_cls: 0.05849  loss_box_reg: 0.169  loss_mask: 0.2165  loss_rpn_cls: 0.0006046  loss_rpn_loc: 0.004797    time: 0.3468  last_time: 0.3484  data_time: 0.0089  last_data_time: 0.0115   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:11 d2.utils.events]:  eta: 0:07:24  iter: 1719  total_loss: 0.5202  loss_cls: 0.06431  loss_box_reg: 0.212  loss_mask: 0.2144  loss_rpn_cls: 0.0004283  loss_rpn_loc: 0.004162    time: 0.3470  last_time: 0.3594  data_time: 0.0131  last_data_time: 0.0226   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:18 d2.utils.events]:  eta: 0:07:18  iter: 1739  total_loss: 0.4323  loss_cls: 0.05681  loss_box_reg: 0.1959  loss_mask: 0.1886  loss_rpn_cls: 0.0008724  loss_rpn_loc: 0.005785    time: 0.3471  last_time: 0.3859  data_time: 0.0073  last_data_time: 0.0051   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:25 d2.utils.events]:  eta: 0:07:11  iter: 1759  total_loss: 0.4986  loss_cls: 0.07125  loss_box_reg: 0.2226  loss_mask: 0.2029  loss_rpn_cls: 0.0001793  loss_rpn_loc: 0.004238    time: 0.3471  last_time: 0.3538  data_time: 0.0097  last_data_time: 0.0072   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:32 d2.utils.events]:  eta: 0:07:04  iter: 1779  total_loss: 0.475  loss_cls: 0.0678  loss_box_reg: 0.1926  loss_mask: 0.1876  loss_rpn_cls: 0.001277  loss_rpn_loc: 0.004376    time: 0.3471  last_time: 0.3385  data_time: 0.0074  last_data_time: 0.0118   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:39 d2.utils.events]:  eta: 0:06:57  iter: 1799  total_loss: 0.4369  loss_cls: 0.04586  loss_box_reg: 0.1625  loss_mask: 0.208  loss_rpn_cls: 0.000595  loss_rpn_loc: 0.003928    time: 0.3470  last_time: 0.3484  data_time: 0.0114  last_data_time: 0.0121   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:46 d2.utils.events]:  eta: 0:06:50  iter: 1819  total_loss: 0.5032  loss_cls: 0.07367  loss_box_reg: 0.2123  loss_mask: 0.2186  loss_rpn_cls: 0.0005696  loss_rpn_loc: 0.003819    time: 0.3468  last_time: 0.2765  data_time: 0.0065  last_data_time: 0.0050   lr: 0.00025  max_mem: 2959M
# [04/05 13:32:53 d2.utils.events]:  eta: 0:06:43  iter: 1839  total_loss: 0.4382  loss_cls: 0.05299  loss_box_reg: 0.167  loss_mask: 0.1883  loss_rpn_cls: 0.0003756  loss_rpn_loc: 0.003269    time: 0.3470  last_time: 0.3466  data_time: 0.0094  last_data_time: 0.0052   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:00 d2.utils.events]:  eta: 0:06:37  iter: 1859  total_loss: 0.3974  loss_cls: 0.04851  loss_box_reg: 0.1463  loss_mask: 0.1906  loss_rpn_cls: 0.0002626  loss_rpn_loc: 0.00343    time: 0.3470  last_time: 0.3870  data_time: 0.0094  last_data_time: 0.0054   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:07 d2.utils.events]:  eta: 0:06:30  iter: 1879  total_loss: 0.4344  loss_cls: 0.05971  loss_box_reg: 0.1881  loss_mask: 0.1819  loss_rpn_cls: 0.0008092  loss_rpn_loc: 0.004523    time: 0.3472  last_time: 0.3725  data_time: 0.0119  last_data_time: 0.0127   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:14 d2.utils.events]:  eta: 0:06:23  iter: 1899  total_loss: 0.4643  loss_cls: 0.05471  loss_box_reg: 0.1958  loss_mask: 0.1845  loss_rpn_cls: 0.000775  loss_rpn_loc: 0.00401    time: 0.3472  last_time: 0.3446  data_time: 0.0089  last_data_time: 0.0174   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:21 d2.utils.events]:  eta: 0:06:16  iter: 1919  total_loss: 0.4463  loss_cls: 0.05583  loss_box_reg: 0.1871  loss_mask: 0.1834  loss_rpn_cls: 0.000358  loss_rpn_loc: 0.003967    time: 0.3473  last_time: 0.3912  data_time: 0.0108  last_data_time: 0.0050   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:28 d2.utils.events]:  eta: 0:06:09  iter: 1939  total_loss: 0.4164  loss_cls: 0.05699  loss_box_reg: 0.1502  loss_mask: 0.1618  loss_rpn_cls: 0.001172  loss_rpn_loc: 0.00432    time: 0.3473  last_time: 0.3431  data_time: 0.0091  last_data_time: 0.0254   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:35 d2.utils.events]:  eta: 0:06:02  iter: 1959  total_loss: 0.4313  loss_cls: 0.05212  loss_box_reg: 0.158  loss_mask: 0.1867  loss_rpn_cls: 0.0001918  loss_rpn_loc: 0.004182    time: 0.3473  last_time: 0.3048  data_time: 0.0097  last_data_time: 0.0050   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:42 d2.utils.events]:  eta: 0:05:57  iter: 1979  total_loss: 0.4018  loss_cls: 0.04413  loss_box_reg: 0.163  loss_mask: 0.1829  loss_rpn_cls: 0.0004834  loss_rpn_loc: 0.003016    time: 0.3474  last_time: 0.4072  data_time: 0.0096  last_data_time: 0.0118   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:50 d2.utils.events]:  eta: 0:05:50  iter: 1999  total_loss: 0.4953  loss_cls: 0.06299  loss_box_reg: 0.1945  loss_mask: 0.1976  loss_rpn_cls: 0.0003397  loss_rpn_loc: 0.003643    time: 0.3475  last_time: 0.3848  data_time: 0.0129  last_data_time: 0.0052   lr: 0.00025  max_mem: 2959M
# [04/05 13:33:59 d2.utils.events]:  eta: 0:05:43  iter: 2019  total_loss: 0.4229  loss_cls: 0.05761  loss_box_reg: 0.183  loss_mask: 0.178  loss_rpn_cls: 0.0004736  loss_rpn_loc: 0.003649    time: 0.3478  last_time: 0.4363  data_time: 0.0148  last_data_time: 0.0353   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:34:06 d2.utils.events]:  eta: 0:05:36  iter: 2039  total_loss: 0.3573  loss_cls: 0.04624  loss_box_reg: 0.1477  loss_mask: 0.154  loss_rpn_cls: 0.000427  loss_rpn_loc: 0.004042    time: 0.3479  last_time: 0.3931  data_time: 0.0066  last_data_time: 0.0054   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:34:13 d2.utils.events]:  eta: 0:05:29  iter: 2059  total_loss: 0.379  loss_cls: 0.0485  loss_box_reg: 0.1528  loss_mask: 0.1749  loss_rpn_cls: 0.0005918  loss_rpn_loc: 0.003444    time: 0.3480  last_time: 0.3410  data_time: 0.0140  last_data_time: 0.0056   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:34:20 d2.utils.events]:  eta: 0:05:21  iter: 2079  total_loss: 0.3803  loss_cls: 0.05079  loss_box_reg: 0.1428  loss_mask: 0.1723  loss_rpn_cls: 0.0006659  loss_rpn_loc: 0.004004    time: 0.3480  last_time: 0.3199  data_time: 0.0076  last_data_time: 0.0045   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:34:27 d2.utils.events]:  eta: 0:05:15  iter: 2099  total_loss: 0.365  loss_cls: 0.0459  loss_box_reg: 0.1473  loss_mask: 0.1672  loss_rpn_cls: 0.000156  loss_rpn_loc: 0.003833    time: 0.3480  last_time: 0.3824  data_time: 0.0133  last_data_time: 0.0053   lr: 2.5e-05  max_mem: 2959M
# ...
# [04/05 13:36:06 d2.utils.events]:  eta: 0:03:37  iter: 2379  total_loss: 0.3351  loss_cls: 0.04185  loss_box_reg: 0.1179  loss_mask: 0.1727  loss_rpn_cls: 0.0002158  loss_rpn_loc: 0.003141    time: 0.3485  last_time: 0.3842  data_time: 0.0065  last_data_time: 0.0051   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:36:13 d2.utils.events]:  eta: 0:03:30  iter: 2399  total_loss: 0.3392  loss_cls: 0.03804  loss_box_reg: 0.1237  loss_mask: 0.1665  loss_rpn_cls: 0.0002775  loss_rpn_loc: 0.004395    time: 0.3486  last_time: 0.3810  data_time: 0.0125  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:36:20 d2.utils.events]:  eta: 0:03:23  iter: 2419  total_loss: 0.3103  loss_cls: 0.04262  loss_box_reg: 0.1158  loss_mask: 0.1371  loss_rpn_cls: 0.001178  loss_rpn_loc: 0.003156    time: 0.3486  last_time: 0.3454  data_time: 0.0077  last_data_time: 0.0065   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:36:27 d2.utils.events]:  eta: 0:03:16  iter: 2439  total_loss: 0.33  loss_cls: 0.04185  loss_box_reg: 0.1305  loss_mask: 0.1727  loss_rpn_cls: 0.0003087  loss_rpn_loc: 0.003173    time: 0.3487  last_time: 0.3961  data_time: 0.0092  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:36:34 d2.utils.events]:  eta: 0:03:09  iter: 2459  total_loss: 0.3134  loss_cls: 0.04134  loss_box_reg: 0.1278  loss_mask: 0.1419  loss_rpn_cls: 0.0003591  loss_rpn_loc: 0.003784    time: 0.3487  last_time: 0.3050  data_time: 0.0094  last_data_time: 0.0045   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:36:41 d2.utils.events]:  eta: 0:03:02  iter: 2479  total_loss: 0.3223  loss_cls: 0.03786  loss_box_reg: 0.1202  loss_mask: 0.1606  loss_rpn_cls: 0.0004824  loss_rpn_loc: 0.002686    time: 0.3487  last_time: 0.3843  data_time: 0.0135  last_data_time: 0.0055   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:36:49 d2.utils.events]:  eta: 0:02:55  iter: 2499  total_loss: 0.3369  loss_cls: 0.03663  loss_box_reg: 0.1149  loss_mask: 0.1629  loss_rpn_cls: 0.0004024  loss_rpn_loc: 0.003816    time: 0.3487  last_time: 0.3761  data_time: 0.0068  last_data_time: 0.0049   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:36:57 d2.utils.events]:  eta: 0:02:48  iter: 2519  total_loss: 0.3103  loss_cls: 0.03178  loss_box_reg: 0.1081  loss_mask: 0.1671  loss_rpn_cls: 9.503e-05  loss_rpn_loc: 0.003432    time: 0.3488  last_time: 0.3576  data_time: 0.0104  last_data_time: 0.0116   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:37:04 d2.utils.events]:  eta: 0:02:41  iter: 2539  total_loss: 0.2963  loss_cls: 0.03822  loss_box_reg: 0.123  loss_mask: 0.1424  loss_rpn_cls: 0.0001264  loss_rpn_loc: 0.003837    time: 0.3488  last_time: 0.3356  data_time: 0.0088  last_data_time: 0.0053   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:37:11 d2.utils.events]:  eta: 0:02:34  iter: 2559  total_loss: 0.315  loss_cls: 0.02899  loss_box_reg: 0.1106  loss_mask: 0.161  loss_rpn_cls: 0.0004272  loss_rpn_loc: 0.00419    time: 0.3489  last_time: 0.4021  data_time: 0.0084  last_data_time: 0.0165   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:37:18 d2.utils.events]:  eta: 0:02:27  iter: 2579  total_loss: 0.3457  loss_cls: 0.03889  loss_box_reg: 0.1319  loss_mask: 0.1716  loss_rpn_cls: 9.716e-05  loss_rpn_loc: 0.003687    time: 0.3489  last_time: 0.3773  data_time: 0.0126  last_data_time: 0.0111   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:37:25 d2.utils.events]:  eta: 0:02:20  iter: 2599  total_loss: 0.3273  loss_cls: 0.0428  loss_box_reg: 0.1286  loss_mask: 0.155  loss_rpn_cls: 0.0001031  loss_rpn_loc: 0.002659    time: 0.3490  last_time: 0.3628  data_time: 0.0084  last_data_time: 0.0061   lr: 2.5e-05  max_mem: 2959M
# [04/05 13:37:33 d2.utils.events]:  eta: 0:02:13  iter: 2619  total_loss: 0.2956  loss_cls: 0.02736  loss_box_reg: 0.1053  loss_mask: 0.1493  loss_rpn_cls: 0.0002846  loss_rpn_loc: 0.00345    time: 0.3491  last_time: 0.3861  data_time: 0.0098  last_data_time: 0.0049   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:37:39 d2.utils.events]:  eta: 0:02:06  iter: 2639  total_loss: 0.3235  loss_cls: 0.03664  loss_box_reg: 0.1016  loss_mask: 0.1618  loss_rpn_cls: 0.0004802  loss_rpn_loc: 0.003061    time: 0.3489  last_time: 0.3192  data_time: 0.0054  last_data_time: 0.0049   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:37:46 d2.utils.events]:  eta: 0:01:59  iter: 2659  total_loss: 0.3069  loss_cls: 0.04224  loss_box_reg: 0.1238  loss_mask: 0.1438  loss_rpn_cls: 0.0001269  loss_rpn_loc: 0.002703    time: 0.3490  last_time: 0.3888  data_time: 0.0133  last_data_time: 0.0146   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:37:53 d2.utils.events]:  eta: 0:01:52  iter: 2679  total_loss: 0.3317  loss_cls: 0.04039  loss_box_reg: 0.1265  loss_mask: 0.162  loss_rpn_cls: 0.0001879  loss_rpn_loc: 0.003638    time: 0.3490  last_time: 0.3705  data_time: 0.0081  last_data_time: 0.0051   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:00 d2.utils.events]:  eta: 0:01:45  iter: 2699  total_loss: 0.3256  loss_cls: 0.04256  loss_box_reg: 0.1118  loss_mask: 0.1562  loss_rpn_cls: 0.0008509  loss_rpn_loc: 0.003266    time: 0.3490  last_time: 0.3883  data_time: 0.0140  last_data_time: 0.0049   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:07 d2.utils.events]:  eta: 0:01:38  iter: 2719  total_loss: 0.3259  loss_cls: 0.03649  loss_box_reg: 0.1177  loss_mask: 0.1593  loss_rpn_cls: 0.0004359  loss_rpn_loc: 0.003492    time: 0.3490  last_time: 0.3364  data_time: 0.0087  last_data_time: 0.0051   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:14 d2.utils.events]:  eta: 0:01:31  iter: 2739  total_loss: 0.3048  loss_cls: 0.03942  loss_box_reg: 0.1176  loss_mask: 0.143  loss_rpn_cls: 0.0003679  loss_rpn_loc: 0.00388    time: 0.3491  last_time: 0.3197  data_time: 0.0145  last_data_time: 0.0187   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:22 d2.utils.events]:  eta: 0:01:24  iter: 2759  total_loss: 0.3198  loss_cls: 0.03927  loss_box_reg: 0.1222  loss_mask: 0.1688  loss_rpn_cls: 0.0001653  loss_rpn_loc: 0.003359    time: 0.3492  last_time: 0.3962  data_time: 0.0084  last_data_time: 0.0115   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:29 d2.utils.events]:  eta: 0:01:17  iter: 2779  total_loss: 0.3081  loss_cls: 0.03533  loss_box_reg: 0.1076  loss_mask: 0.1427  loss_rpn_cls: 0.0001627  loss_rpn_loc: 0.002763    time: 0.3492  last_time: 0.3897  data_time: 0.0104  last_data_time: 0.0117   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:36 d2.utils.events]:  eta: 0:01:10  iter: 2799  total_loss: 0.3185  loss_cls: 0.03796  loss_box_reg: 0.1048  loss_mask: 0.1659  loss_rpn_cls: 0.0003605  loss_rpn_loc: 0.004093    time: 0.3492  last_time: 0.3751  data_time: 0.0098  last_data_time: 0.0049   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:43 d2.utils.events]:  eta: 0:01:03  iter: 2819  total_loss: 0.3134  loss_cls: 0.03729  loss_box_reg: 0.1139  loss_mask: 0.1499  loss_rpn_cls: 0.0001191  loss_rpn_loc: 0.003847    time: 0.3493  last_time: 0.3146  data_time: 0.0098  last_data_time: 0.0051   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:50 d2.utils.events]:  eta: 0:00:56  iter: 2839  total_loss: 0.3263  loss_cls: 0.04129  loss_box_reg: 0.1177  loss_mask: 0.1586  loss_rpn_cls: 0.0004445  loss_rpn_loc: 0.003674    time: 0.3493  last_time: 0.3685  data_time: 0.0092  last_data_time: 0.0049   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:38:57 d2.utils.events]:  eta: 0:00:49  iter: 2859  total_loss: 0.3159  loss_cls: 0.04  loss_box_reg: 0.1126  loss_mask: 0.1425  loss_rpn_cls: 0.0002669  loss_rpn_loc: 0.003405    time: 0.3492  last_time: 0.3718  data_time: 0.0095  last_data_time: 0.0170   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:04 d2.utils.events]:  eta: 0:00:42  iter: 2879  total_loss: 0.3075  loss_cls: 0.03344  loss_box_reg: 0.09795  loss_mask: 0.1659  loss_rpn_cls: 0.0007105  loss_rpn_loc: 0.004284    time: 0.3493  last_time: 0.3919  data_time: 0.0121  last_data_time: 0.0208   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:11 d2.utils.events]:  eta: 0:00:35  iter: 2899  total_loss: 0.3226  loss_cls: 0.04432  loss_box_reg: 0.1262  loss_mask: 0.1433  loss_rpn_cls: 0.0002303  loss_rpn_loc: 0.003561    time: 0.3493  last_time: 0.3277  data_time: 0.0109  last_data_time: 0.0057   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:18 d2.utils.events]:  eta: 0:00:28  iter: 2919  total_loss: 0.302  loss_cls: 0.03531  loss_box_reg: 0.1085  loss_mask: 0.1615  loss_rpn_cls: 0.0002157  loss_rpn_loc: 0.003473    time: 0.3493  last_time: 0.3246  data_time: 0.0099  last_data_time: 0.0058   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:25 d2.utils.events]:  eta: 0:00:21  iter: 2939  total_loss: 0.3143  loss_cls: 0.04153  loss_box_reg: 0.1155  loss_mask: 0.1509  loss_rpn_cls: 0.0005202  loss_rpn_loc: 0.002964    time: 0.3493  last_time: 0.3824  data_time: 0.0083  last_data_time: 0.0054   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:32 d2.utils.events]:  eta: 0:00:14  iter: 2959  total_loss: 0.3116  loss_cls: 0.03105  loss_box_reg: 0.1082  loss_mask: 0.161  loss_rpn_cls: 0.0002429  loss_rpn_loc: 0.00304    time: 0.3493  last_time: 0.3425  data_time: 0.0114  last_data_time: 0.0145   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:39 d2.utils.events]:  eta: 0:00:07  iter: 2979  total_loss: 0.3718  loss_cls: 0.04301  loss_box_reg: 0.1267  loss_mask: 0.1641  loss_rpn_cls: 0.0002332  loss_rpn_loc: 0.003185    time: 0.3493  last_time: 0.3573  data_time: 0.0095  last_data_time: 0.0050   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:49 d2.utils.events]:  eta: 0:00:00  iter: 2999  total_loss: 0.2964  loss_cls: 0.03585  loss_box_reg: 0.09807  loss_mask: 0.1352  loss_rpn_cls: 0.0001105  loss_rpn_loc: 0.002959    time: 0.3494  last_time: 0.3717  data_time: 0.0112  last_data_time: 0.0052   lr: 2.5e-06  max_mem: 2959M
# [04/05 13:39:49 d2.engine.hooks]: Overall training speed: 2998 iterations in 0:17:27 (0.3495 s / it)
# [04/05 13:39:49 d2.engine.hooks]: Total training time: 0:17:44 (0:00:16 on hooks)
# WARNING [04/05 13:39:49 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/05 13:39:49 d2.data.datasets.coco]: Loaded 35 images in COCO format from /content/car_damage_dataset_coco/valid/_annotations.coco.json
# [04/05 13:39:49 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [04/05 13:39:49 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/05 13:39:49 d2.data.common]: Serializing 35 elements to byte tensors and concatenating them all ...
# [04/05 13:39:49 d2.data.common]: Serialized dataset takes 0.03 MiB
# WARNING [04/05 13:39:49 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [04/05 13:39:49 d2.evaluation.evaluator]: Start inference on 35 batches
# [04/05 13:39:51 d2.evaluation.evaluator]: Inference done 11/35. Dataloading: 0.0023 s/iter. Inference: 0.0873 s/iter. Eval: 0.0054 s/iter. Total: 0.0950 s/iter. ETA=0:00:02
# [04/05 13:39:53 d2.evaluation.evaluator]: Total inference time: 0:00:02.810101 (0.093670 s / iter per device, on 1 devices)
# [04/05 13:39:53 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:02 (0.085546 s / iter per device, on 1 devices)
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Saving results to ./output/eval/coco_instances_results.json
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.282
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 10.894 | 29.945 | 6.055  |  nan  | 8.911 | 12.119 |
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP    | category   | AP    | category   | AP     |
# |:-----------|:------|:-----------|:------|:-----------|:-------|
# | minor      | 5.205 | moderate   | 4.504 | severe     | 22.974 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/05 13:39:53 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.093
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.182
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 7.297 | 23.911 | 0.935  |  nan  | 2.376 | 9.311 |
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [04/05 13:39:53 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP    | category   | AP    | category   | AP     |
# |:-----------|:------|:-----------|:------|:-----------|:-------|
# | minor      | 4.275 | moderate   | 1.118 | severe     | 16.498 |
# [04/05 13:39:53 d2.engine.defaults]: Evaluation results for car_dataset_val in csv format:
# [04/05 13:39:53 d2.evaluation.testing]: copypaste: Task: bbox
# [04/05 13:39:53 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/05 13:39:53 d2.evaluation.testing]: copypaste: 10.8941,29.9450,6.0550,nan,8.9109,12.1185
# [04/05 13:39:53 d2.evaluation.testing]: copypaste: Task: segm
# [04/05 13:39:53 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/05 13:39:53 d2.evaluation.testing]: copypaste: 7.2971,23.9112,0.9351,nan,2.3762,9.3112

# %%
cfg.OUTPUT_DIR = "/content/drive/MyDrive/car_damage_model_output"
cfg.OUTPUT_DIR = "/content/drive/MyDrive/car_damage_model_output"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
cfg.MODEL.WEIGHTS = "/content/drive/MyDrive/car_damage_model_output/model_final.pth"

# %%
# !cp /content/output/model_final.pth /content/drive/MyDrive/models/model_final.pth

# %%
# !mkdir -p /content/drive/MyDrive/models

# %%
import random
import cv2
import torch
from detectron2.utils.visualizer import Visualizer, ColorMode
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from google.colab.patches import cv2_imshow  # For displaying images in Colab

# Load the trained model configuration
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3  # Ensure this matches the number of classes
cfg.MODEL.WEIGHTS = "/content/drive/MyDrive/model_final.pth"  # Path to your trained model
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Set a confidence threshold
cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"  # Use GPU if available

# Initialize predictor
predictor = DefaultPredictor(cfg)

# Load dataset information
dataset_dicts = DatasetCatalog.get("car_dataset_val")
metadata = MetadataCatalog.get("car_dataset_val")

# Run predictions on a few sample images
for d in random.sample(dataset_dicts, 3):
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)  # Get predictions

    # Visualize the results
    v = Visualizer(im[:, :, ::-1],  # Convert BGR to RGB
                   metadata=metadata,
                   scale=0.5
                   )  # Grayscale unsegmented areas

    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(out.get_image()[:, :, ::-1])  # Display image in Colab
# Out:
# [04/05 13:57:58 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/drive/MyDrive/model_final.pth ...
# WARNING [04/05 13:57:59 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/05 13:57:59 d2.data.datasets.coco]: Loaded 35 images in COCO format from /content/car_damage_dataset_coco/valid/_annotations.coco.json
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 22  # Change based on your dataset
cfg.MODEL.WEIGHTS = "/content/output/model_final.pth"  # Path to trained model
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Confidence threshold
cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

predictor = DefaultPredictor(cfg)
metadata = MetadataCatalog.get("car_dataset_val")  # Use your dataset metadata
# Out:
# [04/05 13:09:19 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/output/model_final.pth ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (4, 1024) in the checkpoint but (23, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (4,) in the checkpoint but (23,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (12, 1024) in the checkpoint but (88, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (12,) in the checkpoint but (88,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (3, 256, 1, 1) in the checkpoint but (22, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (3,) in the checkpoint but (22,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}

# %%
import glob

# Path to test images
test_images = glob.glob("/content/IMG_20241202_121720 (1).jpg")

for img_path in test_images:
    im = cv2.imread(img_path)

    # Run prediction
    outputs = predictor(im)

    # Visualize
    v = Visualizer(im[:, :, ::-1], metadata=metadata, scale=0.5
                   )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

    # Show the result
    plt.figure(figsize=(10, 10))
    plt.imshow(out.get_image()[:, :, ::-1])
    plt.axis("off")
    plt.show()

# %%
import os
file_path = '/content/drive/MyDrive/model_final.pth'
if os.path.exists(file_path):
    print("File exists")
else:
    print("File not found")
# Out:
# File exists

# %%
import glob

# Path to test images
test_images = glob.glob("/content/WhatsApp Image 2025-03-21 at 14.39.22_e1eafb55.jpg")

for img_path in test_images:
    im = cv2.imread(img_path)

    # Run prediction
    outputs = predictor(im)

    # Visualize
    v = Visualizer(im[:, :, ::-1], metadata=metadata, scale=0.5
                   )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

    # Show the result
    plt.figure(figsize=(10, 10))
    plt.imshow(out.get_image()[:, :, ::-1])
    plt.axis("off")
    plt.show()

# %%
# !pip install gradio

# %%
import gradio as gr
import cv2
import numpy as np
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
from PIL import Image

# Define prediction function
def predict_damage(image):
    # Convert PIL Image to NumPy array
    image_np = np.array(image)

    # Ensure it's in the correct format (H, W, C)
    if image_np.shape[-1] == 4:  # Remove alpha channel if present
        image_np = image_np[:, :, :3]

    # Run model prediction
    outputs = predictor(image_np)

    # Visualize results
    v = Visualizer(image_np[:, :, ::-1], MetadataCatalog.get("car_dataset_val"), scale=0.8)
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

    # Convert back to PIL Image
    result_image = Image.fromarray(out.get_image()[:, :, ::-1])

    return result_image

# Launch Gradio UI
gr.Interface(fn=predict_damage, inputs="image", outputs="image", title="Car Damage Detection").launch(debug=True)
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://eb67afdbf42ae4d6fc.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://eb67afdbf42ae4d6fc.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://eb67afdbf42ae4d6fc.gradio.live
